# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/emcdr
# %ls
# Out:
# /content/drive/MyDrive/emcdr
# create_data.py           Latent_Space_Mapping/     __pycache__/
# create_latent_factor.py  main.ipynb                README.md
# data/                    mapping_latent_factor.py  util.py
# eval.py                  model/                    vector/
# Latent_Factor_Modeling/  parameter_setting.py      vscode.ipynb

# %%
import create_data
create_data.load()
# Out:
# max: 9684
# min: 1
# max: 4254
# min: 1
# item_s_val_num :  1163015
# item_t_val_num :  89590
# ...
# user_val_num :  8938
# all users num :  8938
# train users num :  8045
# test users num :  893
# ...
# train users num :  8045
# test users num :  893
# ...
# 8937
# 0
# 344105
# 0
# 8044
# 0
# 61504
# 0
# 8937
# 8045
# 21785
# 0

# %%
% pip install tensorflow==1.14
# Out:
# ...
#      |████████████████████████████████| 109.2MB 80kB/s
# ...
#      |████████████████████████████████| 491kB 42.8MB/s
# ...
#      |████████████████████████████████| 51kB 5.6MB/s
# ...
#      |████████████████████████████████| 3.2MB 40.8MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.0
#     Uninstalling tensorboard-2.4.0:
#       Successfully uninstalled tensorboard-2.4.0
#   Found existing installation: tensorflow 2.4.0
#     Uninstalling tensorflow-2.4.0:
#       Successfully uninstalled tensorflow-2.4.0
# ...

# %%
import create_latent_factor
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
create_latent_factor.doc2vec_source()

# %%
create_latent_factor.doc2vec_target()

# %%
import mapping_latent_factor

# %%
path_s = './vector/users/doc2vec/doc2vec_vector_size=50_epochs=300_source_trained.npy'
path_t = './vector/users/doc2vec/doc2vec_vector_size=50_epochs=300_target_trained.npy'
loss, Xt = mapping_latent_factor.mapping(path_s, path_t, 500)
# Out:
# source domain train :  (8045, 50)
# source domain test  :  (893, 50)
# target domain       :  (8045, 50)
# WARNING:tensorflow:From /content/drive/My Drive/emcdr/mapping_latent_factor.py:21: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/emcdr/Latent_Space_Mapping/mlp.py:25: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/emcdr/Latent_Space_Mapping/mlp.py:31: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/emcdr/Latent_Space_Mapping/mlp.py:53: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# ...

# %%
# show loss
% matplotlib inline
import matplotlib.pyplot as plt

epochs = list(loss.keys())
loss = list(loss.values())
plt.plot(epochs, loss)
