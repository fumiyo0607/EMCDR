# %%
# !pip install colabcode

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from colabcode import ColabCode
ColabCode(port=10000, password="fumiyo0607")
# Out:
# Code Server can be accessed on: NgrokTunnel: "http://3a30c26fd231.ngrok.io" -> "http://localhost:10000"
# [2021-01-14T14:12:09.188Z] info  code-server 3.7.4 11f53784c58f68e7f4c5b3b8dae9407caa41725b
# [2021-01-14T14:12:09.192Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-01-14T14:12:09.203Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-01-14T14:12:09.203Z] info  HTTP server listening on http://127.0.0.1:10000
# [2021-01-14T14:12:09.203Z] info    - Authentication is enabled
# [2021-01-14T14:12:09.203Z] info      - Using password from $PASSWORD
# [2021-01-14T14:12:09.204Z] info    - Not serving HTTPS
